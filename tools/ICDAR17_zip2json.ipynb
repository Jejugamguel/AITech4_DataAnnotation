# %% [markdown]
# ### ICDAR2017 전체 데이터셋을 UFO로 변환

# %%
# 사전 데이터셋 구존

# input/data/ICDAR17_All
### images
##### {file_name}   (이미지 저장소)
### ufo             (annotation.json 저장소)
### zips_ann        
##### all_ann ()    (이미지별 annotation.txt 저장소)

# %%
import zipfile
import pandas as pd
import numpy as np
import re
import glob
import json
import copy
import os

# %%
# 사전작업 1. zip으로 묶인 이미지를 모두 같은 저장소로 합체
save_path = '/opt/ml/input/data/ICDAR17_All/images/'

if len(os.listdir(save_path)) == 0:
    for i in range(1, 9):
        zipfile.ZipFile('/opt/ml/input/data/ICDAR17_All/zips_image/ch8_training_images_{}.zip'.format(i)).extractall(save_path)

# %%
# 사전작업 2. zip으로 묶인 annotation.txt를 모두 같은 저장소로 합체
save_ann_path = '/opt/ml/input/data/ICDAR17_All/zips_ann/all_ann'

if len(os.listdir(save_ann_path)) == 0:
    zipfile.ZipFile('/opt/ml/input/data/ICDAR17_All/zips_ann/ch8_training_localization_transcription_gt_v2.zip').extractall(save_ann_path)

# %%
# 이미지 번호 순서대로 파일이름을 추출
# zip으로 페어링
all_ann_file_name_list = sorted(glob.glob('/opt/ml/input/data/ICDAR17_All/zips_ann/all_ann/*.txt'), key=lambda x : (len(x.split('_')[5]), x))
all_img_file_name_list = sorted(glob.glob('/opt/ml/input/data/ICDAR17_All/images/*'), key=lambda x : (len(x.split('_')[2]), x))
file_name_zip = zip(all_ann_file_name_list, all_img_file_name_list)

# 각 이미지마다 존재하는 annotation.txt를 UFO 포맷의 dict로 재구성
# 조건 1. Latin, Korean 외의 글자는 illegibility=True로 처리 & transcription='###'으로 처리
# 조건 2. orientation은 'Horizontal'로 일괄처리
care_lang = ['Latin', 'Korean']
cp = re.compile('img_[0-9]+[.][A-Za-z]+')

def convert2UFO(txt, img):
    word = {}
    info = {'points' : '', 'transcription' : '', 'language' : '', 'illegibility' : '', 'orientation' : 'Horizontal'}
    
    with open(txt, 'r') as f:
        idx = 0
        while True:
            ann = f.readline()
            if not ann: break
            ann_info = ann.split(',')
            
            points = np.array(list(map(int, ann_info[:8]))).reshape(4, 2)
            language = ann_info[8]
            if language not in care_lang:
                text = '###'
                illegibility = True
                language = 'Others'
            else:
                text = ann_info[9]
                illegibility = False
            
            info['points'] = points.tolist()
            info['transcription'] = text
            info['language'] = language
            info['illegibility'] = illegibility
            word[str(idx)] = copy.deepcopy(info)
            idx += 1
            
    img_name = cp.findall(img)[0]
    return img_name, {'words' : word}

# %%
# UFO 포맷의 dict구조를 생성하고, 이미지별 annotation 정보를 업데이트
annotation = {'images' :{}}

for txt, img in file_name_zip:
    img_name, word = convert2UFO(txt, img)
    if pd.DataFrame(word)['words'].apply(lambda x : x['language'] == 'Others').any():
        continue
    annotation['images'][img_name] = word
    
annotation
# Out:
# {'images': {'img_802.jpg': {'words': {'0': {'points': [[131, 79],
#       [461, 77],
#       [464, 120],
#       [144, 123]],
#      'transcription': 'WELCOME\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[245, 134], [339, 132], [333, 179], [242, 180]],
#      'transcription': 'TO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[101, 188], [490, 190], [490, 253], [90, 248]],
#      'transcription': 'CARLTON\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[206, 257], [268, 260], [262, 288], [206, 287]],
#      'transcription': 'EST\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[280, 260], [367, 260], [366, 289], [279, 287]],
#      'transcription': '1968\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_805.jpg': {'words': {'0': {'points': [[397, 61],
#       [430, 60],
#       [431, 95],
#       [396, 95]],
#      'transcription': 'NO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[403, 104], [515, 102], [516, 132], [402, 133]],
#      'transcription': 'PARKING\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[419, 143], [470, 143], [468, 160], [419, 160]],
#      'transcription': 'EXCEPT\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[473, 142], [499, 142], [499, 159], [473, 159]],
#      'transcription': 'FOR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[429, 171], [490, 170], [489, 200], [428, 202]],
#      'transcription': 'BOB\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[403, 213], [417, 213], [417, 223], [403, 223]],
#      'transcription': 'ALL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[420, 213], [452, 213], [452, 223], [420, 223]],
#      'transcription': 'OTHERS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[454, 213], [474, 213], [474, 222], [454, 222]],
#      'transcription': 'WILL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[477, 212], [488, 212], [488, 222], [477, 222]],
#      'transcription': 'BE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[489, 212], [518, 212], [518, 221], [490, 222]],
#      'transcription': 'TOWED\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_806.jpg': {'words': {'0': {'points': [[151, 259],
#       [310, 262],
#       [310, 284],
#       [151, 283]],
#      'transcription': 'OfficeMax\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[563, 264], [659, 265], [661, 293], [565, 291]],
#      'transcription': 'T-J-maxx\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[210, 306], [255, 307], [254, 317], [211, 318]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_807.jpg': {'words': {'0': {'points': [[690, 204],
#       [788, 211],
#       [788, 231],
#       [684, 224]],
#      'transcription': 'AVENUE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[115, 208], [186, 203], [184, 218], [116, 223]],
#      'transcription': "CHUCKECHEESE'S\n",
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[331, 205], [432, 213], [431, 226], [330, 221]],
#      'transcription': "CHUCKECHEESE'S\n",
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_810.jpg': {'words': {'0': {'points': [[91, 158],
#       [177, 122],
#       [180, 141],
#       [88, 185]],
#      'transcription': 'Madame\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[183, 106], [242, 77], [245, 101], [182, 134]],
#      'transcription': 'Holly\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[85, 190], [309, 70], [321, 125], [83, 271]],
#      'transcription': 'FORTUNE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[108, 240], [308, 137], [321, 199], [118, 316]],
#      'transcription': 'TELLER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[275, 59], [316, 47], [313, 64], [272, 74]],
#      'transcription': 'LUCK\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[83, 286], [117, 270], [116, 287], [82, 301]],
#      'transcription': 'LOVE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[178, 286], [237, 261], [234, 280], [178, 302]],
#      'transcription': 'MONEY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[257, 237], [304, 225], [312, 268], [263, 279]],
#      'transcription': '$5.\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[93, 327], [134, 318], [135, 332], [94, 339]],
#      'transcription': 'SEES\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[138, 318], [232, 298], [233, 310], [136, 330]],
#      'transcription': 'ALL-TELLS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[236, 296], [271, 289], [272, 302], [236, 310]],
#      'transcription': 'ALL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_813.jpg': {'words': {'0': {'points': [[25, 131],
#       [260, 117],
#       [260, 187],
#       [25, 192]],
#      'transcription': 'Reception\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_814.jpg': {'words': {'0': {'points': [[395, 196],
#       [546, 205],
#       [549, 293],
#       [392, 289]],
#      'transcription': 'C12\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[229, 411], [694, 420], [692, 526], [230, 514]],
#      'transcription': 'Harrington\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[357, 550], [589, 544], [589, 633], [351, 644]],
#      'transcription': 'Court\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_815.jpg': {'words': {'0': {'points': [[307, 426],
#       [718, 432],
#       [720, 524],
#       [310, 542]],
#      'transcription': 'CHERIAN\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_817.jpg': {'words': {'0': {'points': [[162, 59],
#       [185, 60],
#       [186, 70],
#       [162, 70]],
#      'transcription': 'THE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[142, 75], [205, 76], [205, 95], [142, 95]],
#      'transcription': 'CORK\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[147, 100], [199, 100], [199, 111], [147, 110]],
#      'transcription': 'FACTORY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[82, 42], [88, 42], [87, 125], [80, 125]],
#      'transcription': '2349RAILROAD\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[156, 113], [177, 113], [176, 120], [155, 120]],
#      'transcription': 'Luxury\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[177, 113], [190, 113], [190, 120], [177, 120]],
#      'transcription': 'Loft\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[155, 119], [190, 120], [190, 125], [155, 126]],
#      'transcription': 'Apartments\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[292, 49], [307, 49], [307, 53], [292, 54]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_820.jpg': {'words': {'0': {'points': [[373, 311],
#       [931, 214],
#       [937, 344],
#       [397, 413]],
#      'transcription': 'Walmart\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_825.jpg': {'words': {'0': {'points': [[450, 194],
#       [659, 242],
#       [651, 337],
#       [432, 299]],
#      'transcription': 'CocaCola\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[965, 412], [1016, 418], [1020, 452], [963, 452]],
#      'transcription': 'DrPepper\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[359, 475], [439, 472], [441, 522], [362, 519]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_827.jpg': {'words': {'0': {'points': [[69, 457],
#       [116, 459],
#       [114, 490],
#       [68, 484]],
#      'transcription': 'ITS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[85, 227], [270, 227], [269, 298], [83, 289]],
#      'transcription': 'TAKE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[94, 304], [260, 308], [259, 371], [95, 371]],
#      'transcription': "EX'S\n",
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[279, 304], [518, 305], [513, 375], [281, 373]],
#      'transcription': 'STUFF\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[91, 375], [285, 384], [277, 463], [100, 457]],
#      'transcription': 'YARD\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[307, 381], [524, 391], [518, 480], [297, 472]],
#      'transcription': 'SALE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[336, 228], [486, 231], [473, 304], [333, 298]],
#      'transcription': 'MY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[122, 463], [157, 463], [158, 493], [119, 490]],
#      'transcription': 'ALL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[165, 466], [254, 463], [254, 493], [167, 494]],
#      'transcription': 'GOTTA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[270, 466], [335, 475], [329, 507], [267, 499]],
#      'transcription': 'GO!\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[357, 479], [478, 489], [461, 535], [350, 514]],
#      'transcription': 'JUST\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[166, 494], [279, 500], [279, 546], [168, 531]],
#      'transcription': 'LIKE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[307, 506], [453, 530], [444, 573], [305, 550]],
#      'transcription': 'HIM!\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_828.jpg': {'words': {'0': {'points': [[85, 79],
#       [407, 85],
#       [406, 176],
#       [85, 174]],
#      'transcription': 'Gabriel\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[78, 204], [419, 205], [413, 245], [74, 248]],
#      'transcription': 'STATION\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_829.jpg': {'words': {'0': {'points': [[134, 245],
#       [193, 241],
#       [193, 272],
#       [131, 276]],
#      'transcription': 'No.\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[202, 242], [370, 235], [360, 293], [202, 299]],
#      'transcription': '6108\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_830.jpg': {'words': {'0': {'points': [[249, 315],
#       [398, 318],
#       [387, 375],
#       [249, 374]],
#      'transcription': 'DRY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[303, 650], [367, 637], [365, 656], [303, 665]],
#      'transcription': 'Champagne\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[276, 874], [412, 897], [410, 930], [270, 907]],
#      'transcription': 'CANADA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[308, 922], [385, 932], [376, 965], [302, 953]],
#      'transcription': 'DRY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[376, 632], [423, 642], [422, 653], [374, 644]],
#      'transcription': 'CANADA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[385, 649], [411, 653], [407, 664], [385, 660]],
#      'transcription': 'DRY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[325, 623], [346, 623], [344, 636], [324, 638]],
#      'transcription': 'The\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[178, 222], [461, 229], [475, 288], [170, 281]],
#      'transcription': 'CANADA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[447, 652], [456, 650], [455, 664], [446, 662]],
#      'transcription': 'of\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[429, 650], [457, 668], [455, 684], [427, 668]],
#      'transcription': 'Ginger\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[207, 1197], [286, 1182], [291, 1216], [213, 1231]],
#      'transcription': 'THE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[313, 1177], [415, 1157], [417, 1192], [315, 1211]],
#      'transcription': 'BEST\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[166, 1258], [217, 1245], [221, 1280], [171, 1293]],
#      'transcription': 'OF\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[241, 1240], [366, 1219], [368, 1252], [248, 1275]],
#      'transcription': 'THEM\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[395, 1209], [464, 1198], [468, 1231], [393, 1246]],
#      'transcription': 'ALL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[195, 1335], [201, 1335], [201, 1342], [195, 1342]],
#      'transcription': 'C\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[390, 1318], [414, 1317], [413, 1324], [390, 1325]],
#      'transcription': 'MADE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[428, 1315], [448, 1315], [447, 1321], [427, 1321]],
#      'transcription': 'USA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[416, 1317], [425, 1317], [425, 1323], [416, 1323]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[202, 1334], [218, 1334], [218, 1342], [202, 1342]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_831.jpg': {'words': {'0': {'points': [[138, 129],
#       [362, 147],
#       [367, 343],
#       [129, 349]],
#      'transcription': '33\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[412, 151], [719, 176], [721, 242], [412, 231]],
#      'transcription': 'Catherine\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[501, 262], [658, 263], [658, 335], [502, 341]],
#      'transcription': 'Road\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_832.jpg': {'words': {'0': {'points': [[445, 279],
#       [1235, 287],
#       [1236, 626],
#       [446, 611]],
#      'transcription': 'Deep\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1303, 266], [2302, 267], [2299, 615], [1311, 625]],
#      'transcription': 'Purple\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1036, 642], [1338, 643], [1343, 906], [1045, 904]],
#      'transcription': 'in\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1423, 612], [2228, 614], [2238, 898], [1424, 905]],
#      'transcription': 'Rock\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_833.jpg': {'words': {'0': {'points': [[1651, 341],
#       [2496, 352],
#       [2501, 540],
#       [1654, 545]],
#      'transcription': 'Jabra\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[358, 992], [956, 989], [950, 1129], [364, 1146]],
#      'transcription': 'ENJOY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[379, 1237], [2539, 1179], [2548, 1441], [394, 1501]],
#      'transcription': 'HANDS-FREE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[387, 1593], [1949, 1548], [1945, 1695], [387, 1742]],
#      'transcription': 'COMMUNICATION\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[2520, 368], [2542, 370], [2545, 397], [2520, 398]],
#      'transcription': 'R\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_834.jpg': {'words': {'0': {'points': [[1909, 1703],
#       [1963, 1703],
#       [1963, 1738],
#       [1910, 1741]],
#      'transcription': 'HP\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1984, 1703], [2182, 1699], [2176, 1735], [1984, 1739]],
#      'transcription': 'LASERJET\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[2296, 262], [2701, 281], [2753, 529], [2253, 525]],
#      'transcription': '80A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[2949, 282], [3137, 289], [3148, 342], [2931, 336]],
#      'transcription': 'CF280A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[2484, 644], [2595, 641], [2590, 687], [2479, 690]],
#      'transcription': 'Black\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[2477, 704], [2569, 701], [2568, 744], [2474, 747]],
#      'transcription': 'Noir\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[2129, 896], [2221, 900], [2218, 938], [2126, 939]],
#      'transcription': 'Print\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[2234, 888], [2438, 891], [2433, 949], [2229, 945]],
#      'transcription': 'Cartridge\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[2109, 952], [2331, 952], [2328, 998], [2110, 997]],
#      'transcription': 'Cartouche\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[2344, 951], [2607, 949], [2608, 1002], [2343, 1012]],
#      'transcription': "d'Impression\n",
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[2089, 1013], [2245, 1012], [2243, 1058], [2088, 1059]],
#      'transcription': 'Tisková\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[2263, 1013], [2404, 1019], [2403, 1057], [2261, 1058]],
#      'transcription': 'Kazeta\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[2020, 1278], [2234, 1283], [2232, 1346], [2018, 1343]],
#      'transcription': 'Superior',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[2249, 1279], [2534, 1274], [2529, 1332], [2248, 1343]],
#      'transcription': 'professional\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[2553, 1275], [2711, 1274], [2710, 1324], [2550, 1324]],
#      'transcription': 'results.\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[2726, 1273], [2851, 1279], [2843, 1331], [2721, 1324]],
#      'transcription': 'Every\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[2862, 1272], [2963, 1274], [2963, 1321], [2857, 1318]],
#      'transcription': 'time.\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[155, 100], [448, 109], [343, 550], [58, 531]],
#      'transcription': 'hp\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[595, 257], [1292, 261], [1280, 398], [608, 395]],
#      'transcription': 'LASERJET\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[1998, 1370], [2079, 1375], [2078, 1413], [1997, 1414]],
#      'transcription': 'Des\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '20': {'points': [[2642, 1365], [2685, 1364], [2681, 1402], [2639, 1403]],
#      'transcription': 'et\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '21': {'points': [[2095, 1360], [2288, 1367], [2286, 1409], [2093, 1412]],
#      'transcription': 'résultats\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '22': {'points': [[2303, 1362], [2632, 1358], [2626, 1408], [2299, 1423]],
#      'transcription': 'professionnels\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '23': {'points': [[2695, 1351], [2748, 1356], [2747, 1403], [2691, 1401]],
#      'transcription': 'de\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '24': {'points': [[2236, 1432], [2267, 1432], [2266, 1473], [2237, 1475]],
#      'transcription': 'à\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '25': {'points': [[2760, 1353], [2911, 1351], [2907, 1410], [2756, 1414]],
#      'transcription': 'qualité\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '26': {'points': [[2458, 1423], [2715, 1421], [2715, 1482], [2459, 1480]],
#      'transcription': 'impression.\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '27': {'points': [[1979, 1432], [2227, 1431], [2223, 1487], [1978, 1491]],
#      'transcription': 'supérieure\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '28': {'points': [[2277, 1426], [2447, 1431], [2446, 1483], [2280, 1482]],
#      'transcription': 'chaque\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '29': {'points': [[2199, 1697], [2282, 1695], [2285, 1731], [2198, 1736]],
#      'transcription': 'PRO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '30': {'points': [[1892, 1762], [1991, 1761], [1990, 1807], [1888, 1810]],
#      'transcription': '400\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '31': {'points': [[2009, 1758], [2161, 1756], [2162, 1810], [2006, 1807]],
#      'transcription': 'M401',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '32': {'points': [[2179, 1755], [2281, 1752], [2281, 1800], [2180, 1802]],
#      'transcription': '400\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '33': {'points': [[2304, 1752], [2443, 1749], [2442, 1795], [2296, 1797]],
#      'transcription': 'M425\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '34': {'points': [[1072, 1065], [1581, 1087], [1554, 1137], [1013, 1104]],
#      'transcription': 'LOS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '35': {'points': [[1140, 984], [1945, 1035], [1891, 1094], [1085, 1049]],
#      'transcription': 'BERLI\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '36': {'points': [[992, 1120], [1872, 1179], [1848, 1223], [930, 1176]],
#      'transcription': 'LONDO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '37': {'points': [[911, 1191], [1810, 1238], [1777, 1287], [839, 1242]],
#      'transcription': 'MIAMI\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '38': {'points': [[823, 1258], [1774, 1307], [1737, 1358], [762, 1312]],
#      'transcription': 'PARIS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '39': {'points': [[731, 1334], [1724, 1372], [1677, 1430], [692, 1389]],
#      'transcription': 'TOKYO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '40': {'points': [[646, 1408], [1467, 1443], [1423, 1500], [574, 1468]],
#      'transcription': 'HONG\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '41': {'points': [[1788, 1106], [1923, 1108], [1890, 1159], [1737, 1150]],
#      'transcription': 'A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '42': {'points': [[1697, 1445], [1852, 1451], [1818, 1523], [1646, 1513]],
#      'transcription': 'K\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '43': {'points': [[528, 1491], [1203, 1517], [1132, 1579], [458, 1555]],
#      'transcription': 'NEW\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '44': {'points': [[435, 1582], [1737, 1600], [1703, 1691], [363, 1647]],
#      'transcription': 'MADRID\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '45': {'points': [[332, 1672], [1024, 1691], [971, 1755], [248, 1737]],
#      'transcription': 'RIO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '46': {'points': [[215, 1760], [1636, 1786], [1608, 1882], [119, 1834]],
#      'transcription': 'SYDNEY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '47': {'points': [[81, 1868], [318, 1869], [269, 1942], [8, 1935]],
#      'transcription': 'B\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '48': {'points': [[1429, 1515], [1800, 1534], [1770, 1585], [1387, 1590]],
#      'transcription': 'YO\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '49': {'points': [[1281, 1691], [1697, 1697], [1654, 1765], [1224, 1753]],
#      'transcription': 'DE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '50': {'points': [[223, 1077], [573, 1101], [530, 1168], [180, 1144]],
#      'transcription': '01\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '51': {'points': [[113, 1151], [541, 1179], [483, 1231], [74, 1204]],
#      'transcription': '85\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '52': {'points': [[20, 1224], [433, 1243], [407, 1298], [14, 1283]],
#      'transcription': '70\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '53': {'points': [[17, 1390], [238, 1392], [162, 1456], [0, 1454]],
#      'transcription': '3\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '54': {'points': [[351, 1864], [1025, 1875], [1014, 1937], [290, 1953]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '55': {'points': [[1943, 1115], [1989, 1118], [1971, 1168], [1918, 1152]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '56': {'points': [[1894, 1179], [1971, 1176], [1954, 1228], [1867, 1219]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '57': {'points': [[1824, 1538], [1876, 1531], [1857, 1599], [1791, 1589]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_835.jpg': {'words': {'0': {'points': [[660, 101],
#       [1049, 129],
#       [1051, 204],
#       [656, 202]],
#      'transcription': 'THE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1325, 107], [1862, 137], [1861, 215], [1318, 205]],
#      'transcription': 'VERY\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[2123, 124], [2602, 164], [2591, 229], [2116, 217]],
#      'transcription': 'BEST\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[2840, 145], [3017, 158], [3006, 248], [2831, 236]],
#      'transcription': 'OF\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[638, 274], [3033, 278], [3047, 630], [641, 622]],
#      'transcription': 'OTIS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[735, 691], [2983, 674], [2971, 845], [748, 884]],
#      'transcription': 'REDDING\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_836.jpg': {'words': {'0': {'points': [[322, 741],
#       [905, 762],
#       [903, 944],
#       [322, 930]],
#      'transcription': 'N300\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[976, 759], [1771, 768], [1768, 961], [1028, 942]],
#      'transcription': 'Wireless\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1847, 768], [2549, 782], [2545, 1013], [1850, 1002]],
#      'transcription': 'Gigabit\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[2623, 793], [3189, 841], [3187, 984], [2615, 970]],
#      'transcription': 'Router\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[312, 1024], [940, 1033], [954, 1127], [319, 1119]],
#      'transcription': 'WNR3500L\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[1333, 1745], [1644, 1719], [1631, 1774], [1345, 1798]],
#      'transcription': 'NETGEAR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_838.jpg': {'words': {'0': {'points': [[742, 792],
#       [1424, 809],
#       [1419, 1006],
#       [741, 984]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[744, 1091], [1008, 1104], [1006, 1195], [745, 1188]],
#      'transcription': 'Ellipse\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1041, 1103], [1265, 1112], [1269, 1193], [1045, 1180]],
#      'transcription': 'MAX\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[747, 1206], [921, 1214], [916, 1295], [748, 1281]],
#      'transcription': '600\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_839.jpg': {'words': {'0': {'points': [[1374, 511],
#       [1933, 496],
#       [1940, 641],
#       [1373, 654]],
#      'transcription': 'MGE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1377, 697], [1514, 693], [1516, 742], [1380, 746]],
#      'transcription': 'UPS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1571, 691], [1938, 682], [1941, 731], [1571, 740]],
#      'transcription': 'SYSTEMS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1385, 922], [1941, 906], [1941, 962], [1389, 972]],
#      'transcription': 'www.mgeups.com\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1384, 1029], [1953, 1024], [1958, 1108], [1384, 1117]],
#      'transcription': 'Protection\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[1385, 1148], [1728, 1155], [1727, 1228], [1387, 1235]],
#      'transcription': 'Center\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[1765, 1141], [1952, 1134], [1956, 1222], [1763, 1227]],
#      'transcription': '675\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[867, 1322], [958, 1318], [970, 1357], [870, 1363]],
#      'transcription': '7.1A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[2388, 1242], [2476, 1241], [2491, 1281], [2389, 1282]],
#      'transcription': '2.9A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[2298, 1286], [2566, 1288], [2586, 1333], [2301, 1331]],
#      'transcription': '400W;675VA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_840.jpg': {'words': {'0': {'points': [[1676, 976],
#       [2623, 912],
#       [2621, 1028],
#       [1661, 1095]],
#      'transcription': 'MOODY!!\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1370, 497], [2123, 482], [2099, 597], [1411, 617]],
#      'transcription': 'WHEN\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[2383, 465], [2800, 464], [2788, 567], [2380, 587]],
#      'transcription': 'GET\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1628, 656], [2607, 613], [2620, 743], [1610, 773]],
#      'transcription': 'HUNGRY',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1843, 803], [1923, 799], [1910, 918], [1830, 923]],
#      'transcription': 'I\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[2027, 797], [2479, 775], [2457, 884], [2015, 913]],
#      'transcription': 'GET\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[2220, 478], [2296, 476], [2280, 589], [2203, 592]],
#      'transcription': 'I\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[502, 372], [706, 377], [718, 553], [528, 562]],
#      'transcription': 'EAT\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[329, 997], [946, 966], [977, 1115], [343, 1153]],
#      'transcription': 'DINER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[133, 635], [1088, 618], [1100, 866], [164, 904]],
#      'transcription': "MOODY'S\n",
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[227, 1247], [951, 1199], [929, 1279], [272, 1325]],
#      'transcription': 'WALDOBORO',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[951, 1194], [1262, 1173], [1270, 1237], [960, 1264]],
#      'transcription': 'MAINE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[1274, 1874], [1922, 1788], [1930, 1892], [1282, 1991]],
#      'transcription': 'SAMSUNG\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_841.jpg': {'words': {'0': {'points': [[739, 1836],
#       [922, 1821],
#       [924, 1862],
#       [741, 1872]],
#      'transcription': 'Internet',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[309, 280], [1557, 278], [1578, 445], [328, 461]],
#      'transcription': 'NETGEAR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[727, 495], [890, 493], [897, 580], [732, 583]],
#      'transcription': 'with\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[926, 501], [1339, 486], [1342, 571], [931, 582]],
#      'transcription': 'Innovation\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1365, 689], [1815, 679], [1812, 751], [1366, 762]],
#      'transcription': 'Broadband\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[1363, 492], [1406, 488], [1404, 516], [1361, 516]],
#      'transcription': 'TM\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[1367, 801], [1518, 798], [1521, 864], [1372, 869]],
#      'transcription': 'DSL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[1553, 791], [1841, 785], [1844, 853], [1546, 864]],
#      'transcription': 'Modem\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[2834, 255], [3012, 256], [3009, 298], [2816, 296]],
#      'transcription': 'ADSL2\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[2829, 319], [3001, 317], [3000, 360], [2818, 360]],
#      'transcription': 'Modem\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[1372, 969], [1596, 962], [1597, 1006], [1374, 1016]],
#      'transcription': 'DM111P\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[1230, 1188], [1480, 1177], [1482, 1213], [1234, 1225]],
#      'transcription': 'NETGEAR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[2559, 1389], [2848, 1374], [2850, 1438], [2559, 1455]],
#      'transcription': 'Supports\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[2509, 1473], [2804, 1463], [2805, 1514], [2522, 1533]],
#      'transcription': 'Windows\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[2838, 1461], [2880, 1458], [2860, 1509], [2841, 1512]],
#      'transcription': '7\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[541, 1785], [748, 1769], [756, 1807], [551, 1821]],
#      'transcription': 'Connects\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[760, 1774], [843, 1769], [846, 1809], [763, 1812]],
#      'transcription': 'you\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[855, 1758], [899, 1757], [902, 1796], [859, 1793]],
#      'transcription': 'to\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[914, 1761], [1013, 1758], [1011, 1782], [917, 1799]],
#      'transcription': 'your\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[1025, 1744], [1259, 1727], [1262, 1764], [1030, 1781]],
#      'transcription': 'broadband\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '20': {'points': [[1275, 1726], [1435, 1717], [1442, 1751], [1276, 1766]],
#      'transcription': 'Internet\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '21': {'points': [[1448, 1716], [1588, 1700], [1592, 1738], [1454, 1752]],
#      'transcription': 'service\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '22': {'points': [[1598, 1697], [1766, 1689], [1768, 1735], [1600, 1743]],
#      'transcription': 'through\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '23': {'points': [[1771, 1693], [1867, 1691], [1861, 1730], [1773, 1732]],
#      'transcription': 'your\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '24': {'points': [[1872, 1680], [2084, 1670], [2086, 1718], [1878, 1726]],
#      'transcription': 'telephone\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '25': {'points': [[2087, 1666], [2158, 1669], [2161, 1700], [2090, 1703]],
#      'transcription': 'line\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '26': {'points': [[551, 1848], [643, 1839], [642, 1877], [558, 1884]],
#      'transcription': 'Surf\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '27': {'points': [[650, 1838], [724, 1831], [726, 1873], [655, 1876]],
#      'transcription': 'the\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '28': {'points': [[347, 510], [698, 509], [703, 587], [351, 590]],
#      'transcription': 'Connect\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '29': {'points': [[933, 1811], [1053, 1808], [1061, 1842], [941, 1853]],
#      'transcription': 'email\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '30': {'points': [[1069, 1805], [1150, 1796], [1155, 1835], [1073, 1843]],
#      'transcription': 'and\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '31': {'points': [[1162, 1797], [1254, 1787], [1256, 1826], [1167, 1835]],
#      'transcription': 'chat\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '32': {'points': [[561, 1913], [748, 1897], [753, 1934], [563, 1951]],
#      'transcription': 'Freedom\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '33': {'points': [[771, 1897], [808, 1895], [811, 1928], [770, 1933]],
#      'transcription': 'to\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '34': {'points': [[822, 1891], [952, 1879], [957, 1918], [829, 1928]],
#      'transcription': 'switch\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '35': {'points': [[973, 1878], [1055, 1875], [1055, 1908], [974, 1915]],
#      'transcription': 'DSL\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '36': {'points': [[1070, 1874], [1260, 1852], [1261, 1897], [1071, 1916]],
#      'transcription': 'providers\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '37': {'points': [[1270, 1855], [1428, 1842], [1435, 1876], [1277, 1889]],
#      'transcription': 'without\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '38': {'points': [[1435, 1834], [1633, 1824], [1634, 1868], [1440, 1878]],
#      'transcription': 'changing\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '39': {'points': [[1637, 1824], [1856, 1809], [1857, 1854], [1640, 1867]],
#      'transcription': 'equipment\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '40': {'points': [[566, 1977], [660, 1975], [667, 2016], [571, 2024]],
#      'transcription': 'Easy\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '41': {'points': [[676, 1972], [792, 1964], [798, 2003], [678, 2013]],
#      'transcription': 'setup\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '42': {'points': [[807, 1956], [896, 1951], [901, 1986], [810, 1991]],
#      'transcription': 'with\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '43': {'points': [[914, 1948], [1036, 1941], [1037, 1975], [915, 1984]],
#      'transcription': 'Smart\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
# ...
#      'orientation': 'Horizontal'},
#     '6': {'points': [[1046, 889], [1121, 899], [1111, 1009], [1042, 998]],
#      'transcription': '66\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[1053, 753], [1122, 757], [1117, 867], [1048, 859]],
#      'transcription': '73\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[1050, 621], [1130, 618], [1124, 729], [1053, 726]],
#      'transcription': '74\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[1055, 489], [1129, 479], [1130, 590], [1059, 593]],
#      'transcription': '02\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2142.jpg': {'words': {'0': {'points': [[1371, 435],
#       [1575, 432],
#       [1643, 1217],
#       [1396, 1214]],
#      'transcription': 'florajet\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1637, 1066], [1696, 1084], [1699, 1211], [1612, 1183]],
#      'transcription': 'Les\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1615, 686], [1677, 692], [1693, 1066], [1634, 1050]],
#      'transcription': 'nouveaux\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1581, 321], [1652, 339], [1717, 686], [1572, 649]],
#      'transcription': 'fleuristes\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1377, 361], [1541, 346], [1535, 395], [1380, 407]],
#      'transcription': '.com\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[699, 769], [1355, 771], [1361, 1013], [705, 1011]],
#      'transcription': 'f\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2143.jpg': {'words': {'0': {'points': [[303, 903],
#       [1419, 353],
#       [1439, 581],
#       [309, 1068]],
#      'transcription': 'optique\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[8, 1192], [231, 1106], [218, 1251], [5, 1341]],
#      'transcription': 'dE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[330, 1044], [529, 977], [533, 1122], [314, 1211]],
#      'transcription': 'la\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[672, 935], [1965, 382], [2039, 536], [673, 1069]],
#      'transcription': 'source\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2144.jpg': {'words': {'0': {'points': [[435, 103],
#       [541, 114],
#       [651, 568],
#       [327, 542]],
#      'transcription': 'À\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[793, 228], [1884, 370], [1875, 673], [778, 581]],
#      'transcription': 'LOUER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1074, 649], [1297, 670], [1288, 781], [1074, 769]],
#      'transcription': 'PAR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[182, 1157], [960, 1226], [936, 1415], [89, 1386]],
#      'transcription': 'Agence\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1031, 1162], [1965, 1180], [1955, 1341], [1016, 1359]],
#      'transcription': 'Saint-Louis\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[113, 1455], [1969, 1455], [1962, 1535], [106, 1535]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2145.jpg': {'words': {'0': {'points': [[697, 964],
#       [1161, 961],
#       [1158, 1047],
#       [694, 1047]],
#      'transcription': 'INSTITUT\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1186, 961], [1272, 958], [1278, 1041], [1189, 1041]],
#      'transcription': 'de\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1300, 963], [1672, 959], [1690, 1035], [1309, 1041]],
#      'transcription': 'BEAUTE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[826, 1124], [1574, 1116], [1581, 1194], [827, 1196]],
#      'transcription': 'Olivia\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2146.jpg': {'words': {'0': {'points': [[234, 652],
#       [1065, 630],
#       [1071, 883],
#       [234, 840]],
#      'transcription': 'CALVISSON\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2147.jpg': {'words': {'0': {'points': [[738, 754],
#       [864, 754],
#       [858, 1121],
#       [756, 1121]],
#      'transcription': 'DISTRIBUÉ\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[765, 602], [861, 605], [864, 726], [765, 726]],
#      'transcription': 'PAR\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1115, 748], [1170, 744], [1173, 983], [1121, 981]],
#      'transcription': 'PARIS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[948, 482], [1225, 534], [1092, 839], [880, 897]],
#      'transcription': 'Rigot\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[923, 871], [1084, 871], [1102, 1276], [898, 1270]],
#      'transcription': 'Perron\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2148.jpg': {'words': {'0': {'points': [[469, 813],
#       [1476, 781],
#       [1513, 1001],
#       [377, 1024]],
#      'transcription': 'ACTIVITÉS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[395, 1053], [1890, 1029], [1946, 1217], [367, 1254]],
#      'transcription': 'MULTISPORTS\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[401, 1311], [767, 1307], [769, 1369], [360, 1380]],
#      'transcription': 'AVEC\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[807, 1303], [1318, 1286], [1344, 1351], [806, 1369]],
#      'transcription': 'ZUMBA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1365, 1282], [1763, 1273], [1821, 1338], [1371, 1350]],
#      'transcription': 'JULIA\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2149.jpg': {'words': {'0': {'points': [[1028, 834],
#       [1683, 840],
#       [1674, 1056],
#       [1019, 1026]],
#      'transcription': 'CHÈQUE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1291, 1041], [1418, 1041], [1414, 1131], [1288, 1131]],
#      'transcription': 'DE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1013, 1140], [1665, 1137], [1649, 1313], [1003, 1328]],
#      'transcription': 'TABLE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[961, 1511], [1423, 1510], [1424, 1533], [962, 1534]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2151.jpg': {'words': {'0': {'points': [[436, 1163],
#       [479, 1163],
#       [533, 1345],
#       [385, 1345]],
#      'transcription': 'A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[595, 1149], [1374, 1118], [1408, 1344], [602, 1347]],
#      'transcription': 'LOUER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2152.jpg': {'words': {'0': {'points': [[24, 1267],
#       [747, 1248],
#       [731, 1369],
#       [2, 1384]],
#      'transcription': 'BOUCHERIE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[815, 1239], [2017, 1196], [2046, 1356], [803, 1367]],
#      'transcription': 'CHARCUTERIE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2153.jpg': {'words': {'0': {'points': [[151, 624],
#       [1825, 661],
#       [1903, 809],
#       [107, 784]],
#      'transcription': 'PATISSERIE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2156.jpg': {'words': {'0': {'points': [[1439, 710],
#       [1507, 717],
#       [1464, 1038],
#       [1390, 998]],
#      'transcription': 'ARTISAN\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[478, 760], [1380, 809], [1353, 1022], [466, 930]],
#      'transcription': 'BOULANGER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[574, 683], [1254, 704], [1244, 852], [561, 828]],
#      'transcription': 'PATISSIER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[416, 846], [459, 849], [447, 930], [407, 930]],
#      'transcription': 'P.εE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[458, 681], [493, 683], [466, 834], [429, 831]],
#      'transcription': 'FOUSSIER\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2157.jpg': {'words': {'0': {'points': [[124, 403],
#       [283, 386],
#       [299, 537],
#       [132, 540]],
#      'transcription': '2\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[225, 562], [685, 553], [697, 992], [251, 990]],
#      'transcription': 'O\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[908, 293], [1053, 287], [1081, 1223], [942, 1214]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2158.jpg': {'words': {'0': {'points': [[604, 1285],
#       [1492, 1304],
#       [1492, 1450],
#       [608, 1453]],
#      'transcription': 'kangourou\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1486, 1168], [1773, 1160], [1773, 1280], [1482, 1277]],
#      'transcription': 'kids\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2159.jpg': {'words': {'0': {'points': [[79, 537],
#       [129, 543],
#       [113, 587],
#       [67, 584]],
#      'transcription': 'A\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[61, 584], [110, 593], [95, 636], [52, 628]],
#      'transcription': '19\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[28, 683], [80, 688], [64, 726], [14, 719]],
#      'transcription': '303\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[724, 1019], [1262, 1034], [1262, 1207], [592, 1205]],
#      'transcription': 'Atelier\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[283, 1248], [741, 1252], [726, 1457], [240, 1452]],
#      'transcription': 'Ness\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[837, 1254], [1591, 1282], [1606, 1477], [806, 1458]],
#      'transcription': 'Couture\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2160.jpg': {'words': {'0': {'points': [[1156, 489],
#       [1257, 494],
#       [1275, 751],
#       [1165, 749]],
#      'transcription': 'Chez\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1266, 423], [1393, 414], [1418, 818], [1297, 818]],
#      'transcription': 'Gérald\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1538, 389], [1683, 822], [1550, 831], [1473, 398]],
#      'transcription': 'Restauration\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1671, 373], [1813, 859], [1711, 868], [1569, 411]],
#      'transcription': 'Traditionnelle\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2161.jpg': {'words': {'0': {'points': [[914, 460],
#       [1328, 454],
#       [1325, 655],
#       [923, 658]],
#      'transcription': 'Non\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[821, 735], [1439, 710], [1445, 951], [823, 935]],
#      'transcription': 'merci',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[744, 1035], [1099, 1022], [1108, 1212], [756, 1226]],
#      'transcription': 'pas\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1151, 988], [1405, 973], [1405, 1168], [1151, 1174]],
#      'transcription': 'de\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[583, 1298], [1529, 1257], [1513, 1455], [602, 1511]],
#      'transcription': 'publicité!\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2162.jpg': {'words': {'0': {'points': [[141, 933],
#       [1340, 1056],
#       [1380, 1202],
#       [104, 1069]],
#      'transcription': 'CINÉ-THÉÂTRE\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[4, 1302], [32, 1303], [28, 1340], [6, 1339]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[768, 1], [910, 1], [894, 112], [749, 90]],
#      'transcription': '###\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   'img_2163.jpg': {'words': {'0': {'points': [[92, 111],
#       [710, 169],
#       [716, 454],
#       [98, 420]],
#      'transcription': 'Cinq\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[787, 126], [1108, 132], [1105, 407], [790, 404]],
#      'transcription': 'de\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1183, 203], [1779, 210], [1785, 407], [1170, 407]],
#      'transcription': 'cœur\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[778, 528], [1427, 531], [1402, 716], [750, 735]],
#      'transcription': 'Théâtre\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1462, 552], [2006, 512], [1999, 701], [1439, 717]],
#      'transcription': 'musical\n',
#      'language': 'Latin',
#      'illegibility': False,
#      'orientation': 'Horizontal'}}},
#   ...}}

# %%
# 완성된 포맷을 json 파일로 저장
with open('ICDAR17_ALL.json', 'w') as f:
    json.dump(annotation, f, indent=2)

# %%
# all : 5803
# any : 2626
