# %% [markdown]
# ### ICDAR2017 전체 데이터셋을 UFO로 변환

# %%
# 사전 데이터셋 구존

# input/data/ICDAR17_All
### images
##### {file_name}   (이미지 저장소)
### ufo             (annotation.json 저장소)
### zips_ann        
##### all_ann ()    (이미지별 annotation.txt 저장소)

# %%
import zipfile
import pandas as pd
import numpy as np
import re
import glob
import json
import os

# %%
# 사전작업 1. zip으로 묶인 이미지를 모두 같은 저장소로 합체
save_path = '/opt/ml/input/data/ICDAR17_All/images/'

if len(os.listdir(save_path)) == 0:
    for i in range(1, 9):
        zipfile.ZipFile('/opt/ml/input/data/ICDAR17_All/zips_image/ch8_training_images_{}.zip'.format(i)).extractall(save_path)

# %%
# 사전작업 2. zip으로 묶인 annotation.txt를 모두 같은 저장소로 합체
save_ann_path = '/opt/ml/input/data/ICDAR17_All/zips_ann/all_ann'

if len(os.listdir(save_ann_path)) == 0:
    zipfile.ZipFile('/opt/ml/input/data/ICDAR17_All/zips_ann/ch8_training_localization_transcription_gt_v2.zip').extractall(save_ann_path)

# %%
# 이미지 번호 순서대로 파일이름을 추출
# zip으로 페어링
all_ann_file_name_list = sorted(glob.glob('/opt/ml/input/data/ICDAR17_All/zips_ann/all_ann/*.txt'), key=lambda x : (len(x.split('_')[5]), x))
all_img_file_name_list = sorted(glob.glob('/opt/ml/input/data/ICDAR17_All/images/*'), key=lambda x : (len(x.split('_')[2]), x))
file_name_zip = zip(all_ann_file_name_list, all_img_file_name_list)

# %%
# 각 이미지마다 존재하는 annotation.txt를 UFO 포맷의 dict로 재구성
# 조건 1. Latin, Korean 외의 글자는 illegibility=True로 처리 & transcription='###'으로 처리
# 조건 2. orientation은 'Horizontal'로 일괄처리
care_lang = ['Latin, Korean']
cp = re.compile('img_[0-9]+[.][A-Za-z]+')

def convert2UFO(txt, img):
    word = {}
    info = {'points' : '', 'transcription' : '', 'language' : '', 'illegibility' : '', 'orientation' : 'Horizontal'}
    
    with open(txt, 'r') as f:
        idx = 0
        while True:
            ann = f.readline()
            if not ann: break
            ann_info = ann.split(',')
            
            points = np.array(list(map(int, ann_info[:8]))).reshape(4, 2)
            language = ann_info[8]
            if language not in care_lang:
                text = '###'
                illegibility = True
            else:
                text = ann_info[9]
                illegibility = False
            
            info['points'] = points.tolist()
            info['transcription'] = text
            info['language'] = language
            info['illegibility'] = illegibility
            word[str(idx)] = info
            idx += 1
            
    img_name = cp.findall(img)[0]
    return img_name, {'words' : word}

# %%
# UFO 포맷의 dict구조를 생성하고, 이미지별 annotation 정보를 업데이트
annotation = {'images' :{}}

for txt, img in file_name_zip:
    img_name, word = convert2UFO(txt, img)
    annotation['images'][img_name] = word
    
annotation
# Out:
# {'images': {'img_1.png': {'words': {'0': {'points': [[107, 249],
#       [149, 248],
#       [148, 264],
#       [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[107, 249], [149, 248], [148, 264], [124, 265]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_2.png': {'words': {'0': {'points': [[22, 141],
#       [108, 141],
#       [108, 209],
#       [21, 209]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[22, 141], [108, 141], [108, 209], [21, 209]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_3.jpg': {'words': {'0': {'points': [[37, 131],
#       [45, 131],
#       [45, 139],
#       [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[37, 131], [45, 131], [45, 139], [37, 139]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_4.jpg': {'words': {'0': {'points': [[216, 121],
#       [267, 121],
#       [266, 136],
#       [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[216, 121], [267, 121], [266, 136], [215, 136]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_5.jpg': {'words': {'0': {'points': [[49, 176],
#       [200, 175],
#       [200, 184],
#       [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[49, 176], [200, 175], [200, 184], [49, 184]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_6.jpg': {'words': {'0': {'points': [[192, 398],
#       [272, 398],
#       [271, 471],
#       [191, 471]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[192, 398], [272, 398], [271, 471], [191, 471]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[192, 398], [272, 398], [271, 471], [191, 471]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[192, 398], [272, 398], [271, 471], [191, 471]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[192, 398], [272, 398], [271, 471], [191, 471]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_7.jpg': {'words': {'0': {'points': [[447, 1339],
#       [507, 1339],
#       [504, 1395],
#       [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[447, 1339], [507, 1339], [504, 1395], [444, 1395]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_8.jpg': {'words': {'0': {'points': [[82, 205],
#       [220, 177],
#       [216, 223],
#       [75, 256]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[82, 205], [220, 177], [216, 223], [75, 256]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[82, 205], [220, 177], [216, 223], [75, 256]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_9.jpg': {'words': {'0': {'points': [[132, 368],
#       [521, 368],
#       [523, 691],
#       [134, 691]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[132, 368], [521, 368], [523, 691], [134, 691]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_10.jpg': {'words': {'0': {'points': [[914, 312],
#       [975, 312],
#       [975, 328],
#       [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '20': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '21': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '22': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '23': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '24': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '25': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '26': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '27': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '28': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '29': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '30': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '31': {'points': [[914, 312], [975, 312], [975, 328], [914, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_11.jpg': {'words': {'0': {'points': [[646, 610],
#       [687, 611],
#       [687, 629],
#       [646, 628]],
#      'transcription': '###',
#      'language': 'Symbols',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[646, 610], [687, 611], [687, 629], [646, 628]],
#      'transcription': '###',
#      'language': 'Symbols',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[646, 610], [687, 611], [687, 629], [646, 628]],
#      'transcription': '###',
#      'language': 'Symbols',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[646, 610], [687, 611], [687, 629], [646, 628]],
#      'transcription': '###',
#      'language': 'Symbols',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_12.jpg': {'words': {'0': {'points': [[135, 369],
#       [152, 369],
#       [152, 387],
#       [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '20': {'points': [[135, 369], [152, 369], [152, 387], [133, 388]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img
 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[365, 311], [404, 316], [403, 330], [363, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[365, 311], [404, 316], [403, 330], [363, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[365, 311], [404, 316], [403, 330], [363, 328]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_25.jpg': {'words': {'0': {'points': [[1262, 1032],
#       [1523, 1019],
#       [1520, 1060],
#       [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '7': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '8': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[1262, 1032], [1523, 1019], [1520, 1060], [1292, 1071]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_26.jpg': {'words': {'0': {'points': [[346, 431],
#       [548, 420],
#       [549, 533],
#       [365, 528]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[346, 431], [548, 420], [549, 533], [365, 528]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[346, 431], [548, 420], [549, 533], [365, 528]],
#      'transcription': '###',
#      'language': 'Arabic',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
# ...
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '9': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '10': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '11': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '12': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '13': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '14': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '15': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '16': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '17': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '18': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '19': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '20': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '21': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '22': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '23': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '24': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '25': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '26': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '27': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '28': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '29': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '30': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '31': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '32': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '33': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '34': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '35': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '36': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '37': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '38': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '39': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '40': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '41': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '42': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '43': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '44': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '45': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '46': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '47': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '48': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '49': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '50': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '51': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '52': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '53': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '54': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '55': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '56': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '57': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '58': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '59': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '60': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '61': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '62': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '63': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '64': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '65': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '66': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '67': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '68': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '69': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '70': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '71': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '72': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '73': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '74': {'points': [[514, 200], [527, 200], [527, 203], [514, 203]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_997.jpg': {'words': {'0': {'points': [[290, 374],
#       [491, 376],
#       [457, 444],
#       [294, 441]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[290, 374], [491, 376], [457, 444], [294, 441]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[290, 374], [491, 376], [457, 444], [294, 441]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_998.jpg': {'words': {'0': {'points': [[98, 65],
#       [130, 68],
#       [129, 80],
#       [97, 77]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[98, 65], [130, 68], [129, 80], [97, 77]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[98, 65], [130, 68], [129, 80], [97, 77]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[98, 65], [130, 68], [129, 80], [97, 77]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_999.jpg': {'words': {'0': {'points': [[186, 538],
#       [413, 538],
#       [412, 635],
#       [188, 633]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[186, 538], [413, 538], [412, 635], [188, 633]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[186, 538], [413, 538], [412, 635], [188, 633]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[186, 538], [413, 538], [412, 635], [188, 633]],
#      'transcription': '###',
#      'language': 'Latin',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   'img_1000.jpg': {'words': {'0': {'points': [[419, 175],
#       [428, 193],
#       [422, 197],
#       [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '1': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '2': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '3': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '4': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '5': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'},
#     '6': {'points': [[419, 175], [428, 193], [422, 197], [413, 181]],
#      'transcription': '###',
#      'language': 'None',
#      'illegibility': True,
#      'orientation': 'Horizontal'}}},
#   ...}}

# %%
# 완성된 포맷을 json 파일로 저장
with open('ICDAR17_ALL.json', 'w') as f:
    json.dump(annotation, f, indent=2)
